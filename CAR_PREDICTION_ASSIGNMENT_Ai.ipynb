# %% [markdown]
# <a href="https://colab.research.google.com/github/ZubiaAhmed6345/Ai-Asssignments/blob/main/CAR_PREDICTION_ASSIGNMENT_Ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras import models
from keras import layers
from keras import regularizers

import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-522fcdf7-a426-4414-863a-0c3966c3d61b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-522fcdf7-a426-4414-863a-0c3966c3d61b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CarPrice_Assignment.csv to CarPrice_Assignment.csv

# %%
car_data = pd.read_csv(io.BytesIO(uploaded['CarPrice_Assignment.csv']))
car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
car_data.iloc[3,2] = 'audi 100ls'
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
final_car = pd.get_dummies(car_data, columns=['CarName',
                                              'symboling',
                                              'fueltype',
                                              'aspiration',
                                              'doornumber',
                                              'carbody',
                                              'drivewheel',
                                              'enginelocation',
                                              'enginetype',
                                              'cylindernumber',
                                              'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
print('train total head', '\n ',train_total.head(10))
print('\n')
print('train total describe', '\n ',train_total.describe())
print('\n')
print('train total dtypes', '\n ',train_total.dtypes)
# Out:
# train total head
#       wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]
#
#
# train total describe
#           wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]
#
#
# train total dtypes
#   wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
mean = train_data.iloc[:,0:13].mean(axis=0)
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy data
test = np.array(test_data.iloc[:]).astype('float32')
test = np.array(test_data.iloc[:]).astype('float32')
test_l= np.array(test_label.astype('float32'))
train_l= np.array(train_label.astype('float32'))
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_18 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
#k fold validation with relu
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf827a320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf9490d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfc0a5680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf827a440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# 141/4
#k-fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfa5e9200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfae8cd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf5fd9680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf4e0ddd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfa5f6dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf5eb7560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfe819d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf827aa70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8532 - mae: 0.6456
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6573 - mae: 0.5530
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4938 - mae: 0.4828
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4587 - mae: 0.4422
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5443 - mae: 0.5342
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9588 - mae: 0.6421
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5663 - mae: 0.4845
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6609 - mae: 0.4885
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5747 - mae: 0.4203
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3271 - mae: 0.3729
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4599 - mae: 0.4369
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4983 - mae: 0.4287
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3608 - mae: 0.4346
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2391 - mae: 0.3368
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3834 - mae: 0.4055
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2252 - mae: 0.3197
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2183 - mae: 0.3395
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4766 - mae: 0.4297
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3254 - mae: 0.3729
# Epoch 20/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2403 - mae: 0.3487
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3555 - mae: 0.3889
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2810 - mae: 0.3649
# Epoch 23/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1910 - mae: 0.2970
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2816 - mae: 0.3355
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4904 - mae: 0.4068
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3075 - mae: 0.3648
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4576 - mae: 0.4393
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3472 - mae: 0.3653
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2102 - mae: 0.3419
# Epoch 30/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5474 - mae: 0.4219
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4892 - mae: 0.3477
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2410 - mae: 0.3288
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3109 - mae: 0.3446
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1485 - mae: 0.2871
# Epoch 35/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6479 - mae: 0.4725
# Epoch 36/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1768 - mae: 0.2938
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1111 - mae: 0.2433
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2969 - mae: 0.3416
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2903 - mae: 0.3074
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2113 - mae: 0.2969
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2709 - mae: 0.3168
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2869 - mae: 0.2952
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3114 - mae: 0.3082
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4600 - mae: 0.3623
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1632 - mae: 0.2666
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2670 - mae: 0.2989
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1956 - mae: 0.2563
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3675 - mae: 0.3607
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1216 - mae: 0.2223
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2445 - mae: 0.2690
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2356 - mae: 0.2877
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3525 - mae: 0.3400
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2388 - mae: 0.3391
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2224 - mae: 0.2702
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1853 - mae: 0.2426
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4149 - mae: 0.3241
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4617 - mae: 0.4065
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1469 - mae: 0.2192
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1530 - mae: 0.2487
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1583 - mae: 0.2495
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3291 - mae: 0.3208
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3217 - mae: 0.3396
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5858 - mae: 0.3677
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3310 - mae: 0.3056
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2331 - mae: 0.2629
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2368 - mae: 0.2835
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0860 - mae: 0.2057
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1710 - mae: 0.2719
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2775 - mae: 0.3011
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2722 - mae: 0.3144
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2410 - mae: 0.2952
# Epoch 72/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2856 - mae: 0.3039
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2518 - mae: 0.2894
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0967 - mae: 0.1899
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2878 - mae: 0.2770
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1661 - mae: 0.2780
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1883 - mae: 0.2786
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1845 - mae: 0.2988
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2253 - mae: 0.2594
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0729 - mae: 0.1748
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2696 - mae: 0.3177
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2589 - mae: 0.2775
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1090 - mae: 0.2292
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5207 - mae: 0.3397
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1598 - mae: 0.2689
# Epoch 86/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.0999 - mae: 0.1858
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1529 - mae: 0.2067
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2166 - mae: 0.2878
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1727 - mae: 0.2802
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2003 - mae: 0.2603
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2227 - mae: 0.2825
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1550 - mae: 0.2159
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1457 - mae: 0.2492
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2631 - mae: 0.2792
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1476 - mae: 0.2285
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2625 - mae: 0.2769
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4518 - mae: 0.3268
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1440 - mae: 0.2408
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4167 - mae: 0.3357
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2758 - mae: 0.2865
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf9499dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4053 - mae: 0.4440
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.2536 - mae: 0.8000
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6164 - mae: 0.5411
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8636 - mae: 0.6499
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4714 - mae: 0.4949
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6984 - mae: 0.5715
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7257 - mae: 0.6081
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4507 - mae: 0.4768
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6954 - mae: 0.5342
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4652 - mae: 0.4732
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5730 - mae: 0.5068
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4029 - mae: 0.4473
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4263 - mae: 0.4395
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4899 - mae: 0.4426
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2240 - mae: 0.3465
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6115 - mae: 0.5016
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3111 - mae: 0.3613
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2923 - mae: 0.3738
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4534 - mae: 0.4540
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3204 - mae: 0.4055
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3921 - mae: 0.4237
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2687 - mae: 0.3762
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3428 - mae: 0.3986
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3332 - mae: 0.3820
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2259 - mae: 0.3502
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4734 - mae: 0.4186
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7129 - mae: 0.5107
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2540 - mae: 0.3872
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2495 - mae: 0.3359
# Epoch 29/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3003 - mae: 0.3512
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1684 - mae: 0.2906
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1977 - mae: 0.3120
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3210 - mae: 0.3661
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3410 - mae: 0.3762
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4288 - mae: 0.3847
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2617 - mae: 0.3243
# Epoch 36/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2084 - mae: 0.3371
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3785 - mae: 0.4210
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2444 - mae: 0.3512
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2668 - mae: 0.3715
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2703 - mae: 0.3500
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3165 - mae: 0.3720
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4172 - mae: 0.4059
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2408 - mae: 0.3136
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1948 - mae: 0.2993
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3534 - mae: 0.3824
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1469 - mae: 0.2920
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.3260
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3449 - mae: 0.3743
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2009 - mae: 0.2690
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3575 - mae: 0.3369
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2004 - mae: 0.3207
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2342 - mae: 0.3378
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2389 - mae: 0.3317
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1915 - mae: 0.2995
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1824 - mae: 0.3093
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3381 - mae: 0.3477
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2831 - mae: 0.3287
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1556 - mae: 0.2620
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3295 - mae: 0.3544
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3314 - mae: 0.3709
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2335 - mae: 0.2793
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0866 - mae: 0.2082
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1087 - mae: 0.2324
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1160 - mae: 0.2467
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2012 - mae: 0.2945
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1460 - mae: 0.2800
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4421 - mae: 0.3462
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7133 - mae: 0.4098
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1475 - mae: 0.2554
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1000 - mae: 0.2112
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2095 - mae: 0.2963
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2774 - mae: 0.2843
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2737 - mae: 0.2915
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1199 - mae: 0.2693
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4266 - mae: 0.3749
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2223 - mae: 0.2896
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2063 - mae: 0.2470
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1778 - mae: 0.2632
# Epoch 79/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1098 - mae: 0.2428
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1529 - mae: 0.2618
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3719 - mae: 0.3402
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2326 - mae: 0.3174
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1622 - mae: 0.2739
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1140 - mae: 0.2261
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1817 - mae: 0.2687
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1256 - mae: 0.2325
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3673 - mae: 0.3413
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2828 - mae: 0.2876
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2770 - mae: 0.3193
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1531 - mae: 0.2672
# Epoch 91/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2141 - mae: 0.2877
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1671 - mae: 0.2741
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4155 - mae: 0.3831
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2179 - mae: 0.2905
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1825 - mae: 0.3152
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2194 - mae: 0.2797
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4283 - mae: 0.3491
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3187 - mae: 0.2960
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3088 - mae: 0.3202
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0854 - mae: 0.2036
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf4d6bc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4427 - mae: 0.4445
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9450 - mae: 0.6643
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0380 - mae: 0.6156
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6695 - mae: 0.5164
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1969 - mae: 0.6969
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5671 - mae: 0.5361
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8224 - mae: 0.6037
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7582 - mae: 0.5466
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7220 - mae: 0.5748
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8667 - mae: 0.6266
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7521 - mae: 0.5868
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8052 - mae: 0.5701
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6256 - mae: 0.5250
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6657 - mae: 0.5616
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5683 - mae: 0.5245
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1691 - mae: 0.6675
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7329 - mae: 0.5399
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4807 - mae: 0.4898
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9299 - mae: 0.6092
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5255 - mae: 0.5361
# Epoch 20/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4993 - mae: 0.4805
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6019 - mae: 0.5592
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4317 - mae: 0.4060
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5358 - mae: 0.4756
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5022 - mae: 0.4441
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3811 - mae: 0.4382
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3751 - mae: 0.4182
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3955 - mae: 0.4372
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5371 - mae: 0.4593
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2740 - mae: 0.3424
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4505 - mae: 0.4670
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3369 - mae: 0.3377
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3668 - mae: 0.3940
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3486 - mae: 0.4062
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6441 - mae: 0.4765
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3589 - mae: 0.4201
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2824 - mae: 0.3471
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3367 - mae: 0.3606
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2488 - mae: 0.3477
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4086 - mae: 0.4127
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5077 - mae: 0.4560
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7691 - mae: 0.5717
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4600 - mae: 0.4251
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5640 - mae: 0.4785
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3238 - mae: 0.3583
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5132 - mae: 0.4456
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4576 - mae: 0.4166
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3113 - mae: 0.3522
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3378 - mae: 0.3655
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5668 - mae: 0.4303
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4689 - mae: 0.4688
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2954 - mae: 0.3523
# Epoch 52/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3449 - mae: 0.3977
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2278 - mae: 0.2966
# Epoch 54/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.7246 - mae: 0.4855
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5144 - mae: 0.4418
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7551 - mae: 0.4697
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2511 - mae: 0.3447
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2652 - mae: 0.3662
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3822 - mae: 0.3245
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3445 - mae: 0.3718
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1497 - mae: 0.2645
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6404 - mae: 0.4733
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2796 - mae: 0.3304
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3114 - mae: 0.3822
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5216 - mae: 0.4088
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4609 - mae: 0.4204
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3899 - mae: 0.3517
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3008 - mae: 0.3394
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3146 - mae: 0.3511
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3605 - mae: 0.3598
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2156 - mae: 0.3470
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1508 - mae: 0.2611
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2744 - mae: 0.3753
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1504 - mae: 0.2710
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2897 - mae: 0.3640
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3109 - mae: 0.3841
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2987 - mae: 0.3011
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4439 - mae: 0.3686
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2840 - mae: 0.3599
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2994 - mae: 0.3427
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2186 - mae: 0.3070
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5079 - mae: 0.4162
# Epoch 83/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4104 - mae: 0.3670
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1690 - mae: 0.2634
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1634 - mae: 0.2567
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3607 - mae: 0.3826
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2160 - mae: 0.2798
# Epoch 88/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1532 - mae: 0.2477
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2585 - mae: 0.3054
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4919 - mae: 0.4065
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3289 - mae: 0.3058
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4485 - mae: 0.3656
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3286 - mae: 0.3698
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3007 - mae: 0.3311
# Epoch 95/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2720 - mae: 0.3344
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5164 - mae: 0.3947
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2134 - mae: 0.2863
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4283 - mae: 0.3727
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2978 - mae: 0.3237
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3463 - mae: 0.2860
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf5ee57a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4418 - mae: 0.4528
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8667 - mae: 0.7405
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6261 - mae: 0.6367
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9958 - mae: 0.7225
# Epoch 4/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4091 - mae: 0.4961
# Epoch 5/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5016 - mae: 0.4815
# Epoch 6/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4776 - mae: 0.4641
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5908 - mae: 0.5143
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3701 - mae: 0.4030
# Epoch 9/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.8668 - mae: 0.5774
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2920 - mae: 0.3658
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6655 - mae: 0.5074
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5130 - mae: 0.4212
# Epoch 13/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5064 - mae: 0.4052
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4065 - mae: 0.4294
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4685 - mae: 0.4408
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2882 - mae: 0.3675
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4374 - mae: 0.4496
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4006 - mae: 0.4293
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4378 - mae: 0.4383
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2910 - mae: 0.3168
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5230 - mae: 0.3593
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4905 - mae: 0.3842
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3606 - mae: 0.4097
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3163 - mae: 0.3481
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4872 - mae: 0.3986
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6262 - mae: 0.4439
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2970 - mae: 0.3340
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3880 - mae: 0.3334
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2744 - mae: 0.3336
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3935 - mae: 0.4063
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3941 - mae: 0.4302
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5259 - mae: 0.4486
# Epoch 33/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3380 - mae: 0.3420
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2841 - mae: 0.3456
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4911 - mae: 0.4450
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2015 - mae: 0.3182
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3777 - mae: 0.4012
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1998 - mae: 0.2912
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2859 - mae: 0.3776
# Epoch 40/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2125 - mae: 0.3352
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2276 - mae: 0.3048
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2606 - mae: 0.3313
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2727 - mae: 0.3485
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3072 - mae: 0.3343
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2651 - mae: 0.3564
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1948 - mae: 0.2640
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1701 - mae: 0.2801
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2627 - mae: 0.3186
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2058 - mae: 0.2358
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3581 - mae: 0.3452
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3141 - mae: 0.3231
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2141 - mae: 0.2936
# Epoch 53/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3828 - mae: 0.4172
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3408 - mae: 0.3458
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3436 - mae: 0.3310
# Epoch 56/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2546 - mae: 0.3314
# Epoch 57/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3998 - mae: 0.3364
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2979 - mae: 0.3434
# Epoch 59/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2378 - mae: 0.3428
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3591 - mae: 0.3315
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2720 - mae: 0.3111
# Epoch 62/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2482 - mae: 0.3482
# Epoch 63/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1711 - mae: 0.2779
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3519 - mae: 0.3307
# Epoch 65/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3495 - mae: 0.3842
# Epoch 66/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2951 - mae: 0.2812
# Epoch 67/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2228 - mae: 0.3068
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2052 - mae: 0.2689
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1974 - mae: 0.2848
# Epoch 70/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2384 - mae: 0.3097
# Epoch 71/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2529 - mae: 0.3217
# Epoch 72/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2235 - mae: 0.3248
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2049 - mae: 0.2816
# Epoch 74/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2274 - mae: 0.2810
# Epoch 75/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1782 - mae: 0.2745
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2698 - mae: 0.2816
# Epoch 77/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3185 - mae: 0.3261
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2025 - mae: 0.2659
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2200 - mae: 0.2882
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1763 - mae: 0.2773
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1698 - mae: 0.2479
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1494 - mae: 0.2303
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3003 - mae: 0.3580
# Epoch 84/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1034 - mae: 0.2023
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1857 - mae: 0.2719
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2214 - mae: 0.2989
# Epoch 87/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3547 - mae: 0.3251
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2311 - mae: 0.2948
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2647 - mae: 0.3251
# Epoch 90/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1406 - mae: 0.2174
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3073 - mae: 0.3077
# Epoch 92/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2834 - mae: 0.3440
# Epoch 93/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4920 - mae: 0.4127
# Epoch 94/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3688 - mae: 0.3751
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4183 - mae: 0.3558
# Epoch 96/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3566 - mae: 0.4049
# Epoch 97/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2004 - mae: 0.2765
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2633 - mae: 0.2978
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2000 - mae: 0.3059
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2315 - mae: 0.2738
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf4cdf7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1123 - mae: 0.2773

# %%
all_scores_relu
# Out:
# [0.3150753080844879, 0.3145143687725067, 0.3822215795516968, 0.250871866941452]

# %%
all_scores_tanh
# Out:
# [0.31342312693595886,
#  0.26613712310791016,
#  0.35702067613601685,
#  0.3142528235912323]

# %%
all_scores_regular
# Out:
# [0.33428695797920227,
#  0.2540833055973053,
#  0.3876607120037079,
#  0.42329680919647217]

# %%
all_scores_drop
# Out:
# [0.4439784586429596,
#  0.4445495009422302,
#  0.45281755924224854,
#  0.27725452184677124]

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfdf334d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1108 - mae: 0.2485

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcfdf333b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0724 - mae: 0.2192

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf3c56a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1051 - mae: 0.2185

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fbcf3c568c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1565 - mae: 0.2806

# %%
#prediction
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[18709.604]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21702.898]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21520.8]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20623.336]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbcfdf507a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbcf82998c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbcf82c54d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbcf82c57a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
